# %% [markdown]
# ## Count insects on yellow sticky traps.
# In this project you can use the computer vision techniques you learned in the first 5 modules to find and count insects on yellow sticky traps. In the data folder you find a collection images made from yellow sticky traps in tomato greenhouses. Try to automatically find and count the insects. The white dots are tomato-greenhouse-whiteflies, so be sure that you detect those as well.
# <table>
# <tr>
#     <td> <img src="data/yellowstickytrap(1).jpg" alt="Drawing" style="width: 350px;"/> </td>
#     <td> <img src="data/yellowstickytrap(2).jpg" alt="Drawing" style="width: 350px;"/> </td>
#     </tr></table>
#
# Here is some code to start. You can copy and paste code from other notebooks as well. Copying is actually a very efficient was to code.

# %%
#import some packages
import cv2
import matplotlib.pyplot as plt

# Function to show an RGB image
def imshow_rgb(img_bgr):
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    plt.imshow(img_rgb)


#load and show the fist image
img1=cv2.imread('data/yellowstickytrap(1).jpg')
imshow_rgb(img1)
